# %% [markdown]
# # Part 2
# Name: Nontapat Pintira<br>
# StudentID: 6088118<br>
# Sec: 1

# %% [markdown]
# ## Exploring Dataset

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
import warnings
warnings.filterwarnings('ignore')

np.random.RandomState(seed=42)

data = pd.read_csv('../data/part1.csv')
data.head()
# Out:
#       MEASURE_DATETIME  STATION_1  STATION_2  STATION_3  STATION_4  STATION_5  \
# 0  2038-09-26 06:30:00  -0.316324  -0.925849  -1.743750  -0.027530   0.696398
# 1  2023-09-27 11:30:00   0.037566  -0.775905  -1.596030   1.392237   2.548514
# 2  2035-12-14 16:30:00   0.563132  -0.958379   2.674633   0.016340   0.906380
# 3  2033-08-08 04:30:00  -2.561410  -0.777853  -3.009222  -0.749824   0.407406
# 4  2025-12-04 07:30:00  -0.277855  -1.035070  -1.440109   1.537169  -0.535542
#
#    STATION_6  STATION_7  STATION_8  STATION_9  ...  STATION_23  STATION_24  \
# 0   0.525047  -1.414893  -0.694111  -0.170765  ...   -1.308261   -1.668797
# 1   0.109574  -2.129368   0.432420  -0.474324  ...    1.067477    0.238867
# 2   0.370453  -1.384990   5.195813   0.074267  ...    0.910014   -0.659133
# 3  -0.119634  -2.528867   2.086702  -1.597778  ...    2.333471   -0.515519
# 4  -0.055808  -1.996289   0.298748  -0.387890  ...    2.114836   -1.645300
#
#    STATION_25  STATION_26  STATION_27  STATION_28  STATION_29  STATION_30  \
# 0    0.364442    2.218959    2.083341    0.908619      13.273           C
# 1   -1.968316    2.687673   -0.621733   -0.089039      10.150           C
# 2    0.223494   -0.121703    9.359885    0.584530      14.181           D
# 3    0.813406    3.056493    0.722678    0.266050      11.590           D
# 4   -0.886256    2.243861    0.740127   -0.034963      11.796           D
#
#    STATION_31  Fail
# 0           5     0
# 1           1     0
# 2           5     0
# 3           3     0
# 4           4     0
#
# [5 rows x 33 columns]

# %%
df = data.copy()

# %%
data2 = pd.read_csv('../data/part2.csv')
data2.head()
# Out:
#       MEASURE_DATETIME  STATION_1  STATION_2  STATION_3  STATION_4  STATION_5  \
# 0  2031-04-11 12:30:00  -6.138515  -0.687542  -1.128065   0.714542   5.450828
# 1  2038-02-26 01:30:00   1.436961  -1.068244  -4.154836   0.571418   1.662306
# 2  2024-01-03 17:30:00   1.476681  -0.767748   0.904137   0.979496   3.324981
# 3  2028-09-17 20:30:00  -5.560943  -1.630303  -2.837705  -0.346441  -1.019634
# 4  2027-06-22 11:30:00  -3.022456  -0.799757  -1.775154   0.785323  -2.952855
#
#    STATION_6  STATION_7  STATION_8  STATION_9  ...  STATION_22  STATION_23  \
# 0   0.499464  -1.755160  -1.051172  -0.859597  ...    0.969499    0.553603
# 1   0.473979  -1.282310   1.226312   0.061424  ...    0.589029    2.616902
# 2  -0.452631   1.045072  -1.691210  -1.437181  ...    0.593108    1.976968
# 3  -0.901688  -1.682851  -0.997941  -0.402375  ...    0.343320    1.225099
# 4  -0.936765  -5.420181  -1.327529  -0.474175  ...    0.244969    0.723094
#
#    STATION_24  STATION_25  STATION_26  STATION_27  STATION_28  STATION_29  \
# 0   -5.046365   -2.877512    1.958936    0.743942    1.354155      11.595
# 1   -3.999245   -0.220411    3.947895   -1.225864   -0.043235      11.000
# 2   -2.434713    1.025172    0.987821    1.446957    1.252020      24.762
# 3   -2.114637    1.080539    2.660239   -0.162291    0.265278      10.200
# 4    0.371546   -1.839682   -0.868708    0.772647    1.000463      42.657
#
#    STATION_30  STATION_31
# 0           B           3
# 1           D           3
# 2           B           7
# 3           B           1
# 4           A           8
#
# [5 rows x 32 columns]

# %%
df2 = data2.copy()

# %% [markdown]
# ### Check for missing value

# %%
df.isnull().sum()
# Out:
# MEASURE_DATETIME    0
# STATION_1           0
# STATION_2           0
# STATION_3           0
# STATION_4           0
# STATION_5           0
# STATION_6           0
# STATION_7           0
# STATION_8           0
# STATION_9           0
# STATION_10          0
# STATION_11          0
# STATION_12          0
# STATION_13          0
# STATION_14          0
# STATION_15          0
# STATION_16          0
# STATION_17          0
# STATION_18          0
# STATION_19          0
# STATION_20          0
# STATION_21          0
# STATION_22          0
# STATION_23          0
# STATION_24          0
# STATION_25          0
# STATION_26          0
# STATION_27          0
# STATION_28          0
# STATION_29          0
# STATION_30          0
# STATION_31          0
# Fail                0
# dtype: int64

# %% [markdown]
# The data has no missing value. That is good for me.

# %% [markdown]
# ### Check the statistical value of the data

# %%
df.describe()
# Out:
#            STATION_1      STATION_2      STATION_3      STATION_4  \
# count  256326.000000  256326.000000  256326.000000  256326.000000
# mean       -1.313971      -0.731119      -0.866843       0.821823
# std         2.195963       0.404456       1.450759       0.814019
# min       -32.503416     -32.343246     -21.872772      -6.115752
# 25%        -2.507817      -0.822090      -1.922183       0.365526
# 50%        -1.209207      -0.732496      -0.880215       0.825745
# 75%        -0.026859      -0.660297       0.218378       1.280313
# max        25.554706      21.834632      18.132254       6.394659
#
#            STATION_5      STATION_6      STATION_7      STATION_8  \
# count  256326.000000  256326.000000  256326.000000  256326.000000
# mean        0.923356      -0.108355      -1.304010       0.579061
# std         2.996013       0.521609       2.174032       2.764076
# min       -22.622136      -7.627565     -50.480777    -226.907545
# 25%        -0.932679      -0.459060      -2.376116      -0.801685
# 50%         0.500939      -0.124929      -1.490907       0.471967
# 75%         2.141427       0.208877      -0.395310       1.803000
# max        56.974184      10.187421      46.186020      70.182400
#
#            STATION_9     STATION_10  ...     STATION_22     STATION_23  \
# count  256326.000000  256326.000000  ...  256326.000000  256326.000000
# mean       -0.493516       0.425331  ...       0.697428       1.435844
# std         0.605447       2.041088  ...       0.627652       0.837940
# min        -3.330241      -9.169622  ...     -44.110812      -3.276974
# 25%        -0.848411      -1.099568  ...       0.535458       0.934858
# 50%        -0.452604       0.358295  ...       0.685902       1.439733
# 75%        -0.054086       1.904804  ...       0.844571       1.934274
# max         4.090935      24.463151  ...      23.225335      10.934170
#
#           STATION_24     STATION_25     STATION_26     STATION_27  \
# count  256326.000000  256326.000000  256326.000000  256326.000000
# mean       -1.181708      -0.349790       2.198160       0.659262
# std         1.991639       1.916044       2.198837       2.667571
# min       -15.434178     -21.405041    -102.290647     -51.660607
# 25%        -2.507894      -1.336195       1.514985      -0.877824
# 50%        -1.153917      -0.450782       2.111582       0.112210
# 75%         0.114718       0.503477       2.759198       1.456231
# max        10.403350      38.077142      83.809017     147.263656
#
#           STATION_28     STATION_29     STATION_31           Fail
# count  256326.000000  256326.000000  256326.000000  256326.000000
# mean        0.283852      18.838225       3.973495       0.001728
# std         1.238322      24.781714       2.597554       0.041537
# min      -120.304674      10.000000       0.000000       0.000000
# 25%        -0.286639      10.560250       2.000000       0.000000
# 50%         0.244250      12.200000       4.000000       0.000000
# 75%         0.837974      17.730000       6.000000       0.000000
# max        43.842061    2579.116000       8.000000       1.000000
#
# [8 rows x 31 columns]

# %% [markdown]
# We can see that some feature has extreme values, we may have to deal with it later on.

# %% [markdown]
# ### Check the distribution of the label.

# %%
df.Fail.value_counts().plot(kind="bar", color=["salmon", "lightblue"])

# %%
df.Fail.value_counts()
# Out:
# 0    255883
# 1       443
# Name: Fail, dtype: int64

# %% [markdown]
# ***
# ### Explore the correlation between features and labels
#
# We are going to see which station is the most correlated with the failure rate

# %%
df.drop('Fail', axis=1).corrwith(df.Fail).plot(kind='bar',
                                               grid=True,
                                               figsize=(10, 8),
                                               title="Correlation with Fail")

# %% [markdown]
# We can clearly see that Station 5 ,21 25, 28 is positively correlated the Failure.
#
# And, Station 7, 13 ,15 is negatively correlated with Failure
#
# ##### Scatter Plot between the STATION_21 and STATION_7

# %%
# Create another figure
plt.figure(figsize=(10, 8))

plt.scatter(df.STATION_21[df.Fail == 1],
            df.STATION_7[df.Fail == 1],
            c="salmon")

plt.scatter(df.STATION_21[df.Fail == 0],
            df.STATION_7[df.Fail == 0],
            c="lightblue")

# Add some helpful info
plt.title("Station 21 vs Station 7")
plt.xlabel("Station 21")
plt.ylabel("Station 7")
plt.grid(b=True)
plt.legend(["Fail", "Not Fail"])

# %% [markdown]
# ### Explore discrete features
# STATION_30 and STATION_31 have discrete features.

# %%
df.STATION_30.value_counts()
# Out:
# B    64267
# A    64193
# D    64068
# C    63798
# Name: STATION_30, dtype: int64

# %%
sns.catplot(x="Fail",
            kind="count",
            hue='STATION_30',
            palette="inferno",
            data=df)

# %%
pd.crosstab([df.STATION_30], [df.Fail],
            margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_b07c22cc_6434_11ea_9090_a402b94ff63brow0_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_b07c22cc_6434_11ea_9090_a402b94ff63brow0_col1 {
#             background-color:  #f7fb66;
#             color:  #000000;
#         }    #T_b07c22cc_6434_11ea_9090_a402b94ff63brow0_col2 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_b07c22cc_6434_11ea_9090_a402b94ff63brow1_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_b07c22cc_6434_11ea_9090_a402b94ff63brow1_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_b07c22cc_6434_11ea_9090_a402b94ff63brow1_col2 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_b07c22cc_6434_11ea_9090_a402b94ff63brow2_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_b07c22cc_6434_11ea_9090_a402b94ff63brow2_col1 {
#             background-color:  #f4fa66;
#             color:  #000000;
#         }    #T_b07c22cc_6434_11ea_9090_a402b94ff63brow2_col2 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_b07c22cc_6434_11ea_9090_a402b94ff63brow3_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_b07c22cc_6434_11ea_9090_a402b94ff63brow3_col1 {
#             background-color:  #f7fb66;
#             color:  #000000;
#         }    #T_b07c22cc_6434_11ea_9090_a402b94ff63brow3_col2 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_b07c22cc_6434_11ea_9090_a402b94ff63brow4_col0 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_b07c22cc_6434_11ea_9090_a402b94ff63brow4_col1 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_b07c22cc_6434_11ea_9090_a402b94ff63brow4_col2 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }</style><table id="T_b07c22cc_6434_11ea_9090_a402b94ff63b" ><thead>    <tr>        <th class="index_name level0" >Fail</th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>        <th class="col_heading level0 col2" >All</th>    </tr>    <tr>        <th class="index_name level0" >STATION_30</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b07c22cc_6434_11ea_9090_a402b94ff63blevel0_row0" class="row_heading level0 row0" >A</th>
#                         <td id="T_b07c22cc_6434_11ea_9090_a402b94ff63brow0_col0" class="data row0 col0" >64081</td>
#                         <td id="T_b07c22cc_6434_11ea_9090_a402b94ff63brow0_col1" class="data row0 col1" >112</td>
#                         <td id="T_b07c22cc_6434_11ea_9090_a402b94ff63brow0_col2" class="data row0 col2" >64193</td>
#             </tr>
#             <tr>
#                         <th id="T_b07c22cc_6434_11ea_9090_a402b94ff63blevel0_row1" class="row_heading level0 row1" >B</th>
#                         <td id="T_b07c22cc_6434_11ea_9090_a402b94ff63brow1_col0" class="data row1 col0" >64166</td>
#                         <td id="T_b07c22cc_6434_11ea_9090_a402b94ff63brow1_col1" class="data row1 col1" >101</td>
#                         <td id="T_b07c22cc_6434_11ea_9090_a402b94ff63brow1_col2" class="data row1 col2" >64267</td>
#             </tr>
#             <tr>
#                         <th id="T_b07c22cc_6434_11ea_9090_a402b94ff63blevel0_row2" class="row_heading level0 row2" >C</th>
#                         <td id="T_b07c22cc_6434_11ea_9090_a402b94ff63brow2_col0" class="data row2 col0" >63681</td>
#                         <td id="T_b07c22cc_6434_11ea_9090_a402b94ff63brow2_col1" class="data row2 col1" >117</td>
#                         <td id="T_b07c22cc_6434_11ea_9090_a402b94ff63brow2_col2" class="data row2 col2" >63798</td>
#             </tr>
#             <tr>
#                         <th id="T_b07c22cc_6434_11ea_9090_a402b94ff63blevel0_row3" class="row_heading level0 row3" >D</th>
#                         <td id="T_b07c22cc_6434_11ea_9090_a402b94ff63brow3_col0" class="data row3 col0" >63955</td>
#                         <td id="T_b07c22cc_6434_11ea_9090_a402b94ff63brow3_col1" class="data row3 col1" >113</td>
#                         <td id="T_b07c22cc_6434_11ea_9090_a402b94ff63brow3_col2" class="data row3 col2" >64068</td>
#             </tr>
#             <tr>
#                         <th id="T_b07c22cc_6434_11ea_9090_a402b94ff63blevel0_row4" class="row_heading level0 row4" >All</th>
#                         <td id="T_b07c22cc_6434_11ea_9090_a402b94ff63brow4_col0" class="data row4 col0" >255883</td>
#                         <td id="T_b07c22cc_6434_11ea_9090_a402b94ff63brow4_col1" class="data row4 col1" >443</td>
#                         <td id="T_b07c22cc_6434_11ea_9090_a402b94ff63brow4_col2" class="data row4 col2" >256326</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# From the result of cross-tabulation, we can see that this feature does not show any correlation with the label

# %%
df.STATION_31.value_counts()
# Out:
# 0    30753
# 2    29835
# 5    29293
# 4    28547
# 8    28491
# 6    28034
# 7    27974
# 1    26980
# 3    26419
# Name: STATION_31, dtype: int64

# %%
sns.catplot(x="Fail",
            kind="count",
            hue='STATION_31',
            palette="inferno",
            data=df)

# %%
pd.crosstab([df.STATION_31], [df.Fail],
            margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_b1225158_6434_11ea_8820_a402b94ff63brow0_col0 {
#             background-color:  #fbfd66;
#             color:  #000000;
#         }    #T_b1225158_6434_11ea_8820_a402b94ff63brow0_col1 {
#             background-color:  #a3d166;
#             color:  #000000;
#         }    #T_b1225158_6434_11ea_8820_a402b94ff63brow0_col2 {
#             background-color:  #fbfd66;
#             color:  #000000;
#         }    #T_b1225158_6434_11ea_8820_a402b94ff63brow1_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_b1225158_6434_11ea_8820_a402b94ff63brow1_col1 {
#             background-color:  #f5fa66;
#             color:  #000000;
#         }    #T_b1225158_6434_11ea_8820_a402b94ff63brow1_col2 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_b1225158_6434_11ea_8820_a402b94ff63brow2_col0 {
#             background-color:  #fcfe66;
#             color:  #000000;
#         }    #T_b1225158_6434_11ea_8820_a402b94ff63brow2_col1 {
#             background-color:  #f3f966;
#             color:  #000000;
#         }    #T_b1225158_6434_11ea_8820_a402b94ff63brow2_col2 {
#             background-color:  #fcfe66;
#             color:  #000000;
#         }    #T_b1225158_6434_11ea_8820_a402b94ff63brow3_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_b1225158_6434_11ea_8820_a402b94ff63brow3_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_b1225158_6434_11ea_8820_a402b94ff63brow3_col2 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_b1225158_6434_11ea_8820_a402b94ff63brow4_col0 {
#             background-color:  #fdfe66;
#             color:  #000000;
#         }    #T_b1225158_6434_11ea_8820_a402b94ff63brow4_col1 {
#             background-color:  #fbfd66;
#             color:  #000000;
#         }    #T_b1225158_6434_11ea_8820_a402b94ff63brow4_col2 {
#             background-color:  #fdfe66;
#             color:  #000000;
#         }    #T_b1225158_6434_11ea_8820_a402b94ff63brow5_col0 {
#             background-color:  #fcfe66;
#             color:  #000000;
#         }    #T_b1225158_6434_11ea_8820_a402b94ff63brow5_col1 {
#             background-color:  #f5fa66;
#             color:  #000000;
#         }    #T_b1225158_6434_11ea_8820_a402b94ff63brow5_col2 {
#             background-color:  #fcfe66;
#             color:  #000000;
#         }    #T_b1225158_6434_11ea_8820_a402b94ff63brow6_col0 {
#             background-color:  #fefe66;
#             color:  #000000;
#         }    #T_b1225158_6434_11ea_8820_a402b94ff63brow6_col1 {
#             background-color:  #fafc66;
#             color:  #000000;
#         }    #T_b1225158_6434_11ea_8820_a402b94ff63brow6_col2 {
#             background-color:  #fefe66;
#             color:  #000000;
#         }    #T_b1225158_6434_11ea_8820_a402b94ff63brow7_col0 {
#             background-color:  #fefe66;
#             color:  #000000;
#         }    #T_b1225158_6434_11ea_8820_a402b94ff63brow7_col1 {
#             background-color:  #dfef66;
#             color:  #000000;
#         }    #T_b1225158_6434_11ea_8820_a402b94ff63brow7_col2 {
#             background-color:  #fefe66;
#             color:  #000000;
#         }    #T_b1225158_6434_11ea_8820_a402b94ff63brow8_col0 {
#             background-color:  #fdfe66;
#             color:  #000000;
#         }    #T_b1225158_6434_11ea_8820_a402b94ff63brow8_col1 {
#             background-color:  #d3e966;
#             color:  #000000;
#         }    #T_b1225158_6434_11ea_8820_a402b94ff63brow8_col2 {
#             background-color:  #fdfe66;
#             color:  #000000;
#         }    #T_b1225158_6434_11ea_8820_a402b94ff63brow9_col0 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_b1225158_6434_11ea_8820_a402b94ff63brow9_col1 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_b1225158_6434_11ea_8820_a402b94ff63brow9_col2 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }</style><table id="T_b1225158_6434_11ea_8820_a402b94ff63b" ><thead>    <tr>        <th class="index_name level0" >Fail</th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>        <th class="col_heading level0 col2" >All</th>    </tr>    <tr>        <th class="index_name level0" >STATION_31</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b1225158_6434_11ea_8820_a402b94ff63blevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_b1225158_6434_11ea_8820_a402b94ff63brow0_col0" class="data row0 col0" >30587</td>
#                         <td id="T_b1225158_6434_11ea_8820_a402b94ff63brow0_col1" class="data row0 col1" >166</td>
#                         <td id="T_b1225158_6434_11ea_8820_a402b94ff63brow0_col2" class="data row0 col2" >30753</td>
#             </tr>
#             <tr>
#                         <th id="T_b1225158_6434_11ea_8820_a402b94ff63blevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_b1225158_6434_11ea_8820_a402b94ff63brow1_col0" class="data row1 col0" >26953</td>
#                         <td id="T_b1225158_6434_11ea_8820_a402b94ff63brow1_col1" class="data row1 col1" >27</td>
#                         <td id="T_b1225158_6434_11ea_8820_a402b94ff63brow1_col2" class="data row1 col2" >26980</td>
#             </tr>
#             <tr>
#                         <th id="T_b1225158_6434_11ea_8820_a402b94ff63blevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_b1225158_6434_11ea_8820_a402b94ff63brow2_col0" class="data row2 col0" >29804</td>
#                         <td id="T_b1225158_6434_11ea_8820_a402b94ff63brow2_col1" class="data row2 col1" >31</td>
#                         <td id="T_b1225158_6434_11ea_8820_a402b94ff63brow2_col2" class="data row2 col2" >29835</td>
#             </tr>
#             <tr>
#                         <th id="T_b1225158_6434_11ea_8820_a402b94ff63blevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_b1225158_6434_11ea_8820_a402b94ff63brow3_col0" class="data row3 col0" >26410</td>
#                         <td id="T_b1225158_6434_11ea_8820_a402b94ff63brow3_col1" class="data row3 col1" >9</td>
#                         <td id="T_b1225158_6434_11ea_8820_a402b94ff63brow3_col2" class="data row3 col2" >26419</td>
#             </tr>
#             <tr>
#                         <th id="T_b1225158_6434_11ea_8820_a402b94ff63blevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_b1225158_6434_11ea_8820_a402b94ff63brow4_col0" class="data row4 col0" >28531</td>
#                         <td id="T_b1225158_6434_11ea_8820_a402b94ff63brow4_col1" class="data row4 col1" >16</td>
#                         <td id="T_b1225158_6434_11ea_8820_a402b94ff63brow4_col2" class="data row4 col2" >28547</td>
#             </tr>
#             <tr>
#                         <th id="T_b1225158_6434_11ea_8820_a402b94ff63blevel0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_b1225158_6434_11ea_8820_a402b94ff63brow5_col0" class="data row5 col0" >29266</td>
#                         <td id="T_b1225158_6434_11ea_8820_a402b94ff63brow5_col1" class="data row5 col1" >27</td>
#                         <td id="T_b1225158_6434_11ea_8820_a402b94ff63brow5_col2" class="data row5 col2" >29293</td>
#             </tr>
#             <tr>
#                         <th id="T_b1225158_6434_11ea_8820_a402b94ff63blevel0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_b1225158_6434_11ea_8820_a402b94ff63brow6_col0" class="data row6 col0" >28015</td>
#                         <td id="T_b1225158_6434_11ea_8820_a402b94ff63brow6_col1" class="data row6 col1" >19</td>
#                         <td id="T_b1225158_6434_11ea_8820_a402b94ff63brow6_col2" class="data row6 col2" >28034</td>

# %% [markdown]
# On the other hand, STATION_31 has a very very very weak correlation with the label

# %% [markdown]
# ******
# ## Preprocessing

# %% [markdown]
# We will try fitting the data into a simple model and see how it performs.

# %% [markdown]
# First I will only select features which show some correlation with the label

# %%
features = [
    'STATION_1', 'STATION_5', 'STATION_7', 'STATION_8', 'STATION_10',
    'STATION_12', 'STATION_13', 'STATION_14', 'STATION_15', 'STATION_19',
    'STATION_21', 'STATION_23', 'STATION_25', 'STATION_28'
]

X = df[features]
y = df['Fail']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,
                                                    y,
                                                    test_size=0.3,
                                                    stratify=df['Fail'])

# %% [markdown]
# ## Modeling

# %% [markdown]
# #### The data is imbalanced so we have to deal with that too
# I use ensemble methods with random undersampling to tackle this issue
#
# I use stratified K-fold since the data is imbalance and I want to preserve the distribution

# %% [markdown]
# Another model that I will try is to
# * First, do oversampling with SMOTE.
# * Second, to random undersampling to normalize the synthesized data.
# * Third, I will use ensemble method, in this case RandomForestClassifier. Since random undersampling works better with ensemble model
# * Fourth, I will evaluate my model using F1 score.

# %%
# random forest on imbalanced dataset with SMOTE oversampling and random undersampling
from numpy import mean
from sklearn.datasets import make_classification
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold
from imblearn.pipeline import Pipeline
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler
from sklearn.feature_selection import RFECV

# define pipeline
model = RandomForestClassifier()
over = SMOTE(sampling_strategy=0.2)
under = RandomUnderSampler(sampling_strategy=0.7)
steps = [('over', over), ('under', under), ('model', model)]
pipeline = Pipeline(steps=steps)

# evaluate pipeline
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
scores = cross_val_score(pipeline,
                         X_train,
                         y_train,
                         scoring='f1',
                         cv=cv,
                         n_jobs=-1)
print('Mean F1: %.3f' % mean(scores))
# Out:
# Mean F1: 0.756

# %%
model.fit(X_train, y_train)

prediction = model.predict(X_test)
print('The F1-score of the RandomForestClassifier is',
      metrics.f1_score(prediction, y_test))
# Out:
# The F1-score of the RandomForestClassifier is 0.8699186991869919

# %% [markdown]
# F1-score is used here because the data is imbalanced and I would like to minimized the number of false negative error.
#
# Moreover, I will use confusion matrix to visualize the model performance.

# %%
cm = confusion_matrix(y_test,
                      prediction,
                      labels=None,
                      sample_weight=None,
                      normalize=None)
fig, ax = plt.subplots(figsize=(8, 8))
ax = sns.heatmap(cm, annot=True, linewidths=0.5, fmt=".2f", cmap="YlGnBu")
bottom, top = ax.get_ylim()
ax.set_ylim(bottom + 0.5, top - 0.5)
# Out:
# (2.0, 0.0)

# %% [markdown]
# #### Label Part 2 dataset

# %%
part2_label = model.predict(df2[features])
part2_label
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
csv = pd.DataFrame(part2_label)
csv.to_csv('label_6088118.csv', index=False)

# %%
df2.describe()
# Out:
#           STATION_1     STATION_2     STATION_3     STATION_4     STATION_5  \
# count  28481.000000  28481.000000  28481.000000  28481.000000  28481.000000
# mean      -1.308528     -0.730408     -0.864333      0.829048      0.920195
# std        2.208971      0.396152      1.457214      0.814218      3.011942
# min      -21.965693     -7.869288     -9.585846     -6.390982    -12.288655
# 25%       -2.506043     -0.822129     -1.934652      0.373255     -0.923421
# 50%       -1.220989     -0.731465     -0.879783      0.830770      0.520899
# 75%       -0.030583     -0.659466      0.216222      1.289922      2.129667
# max       17.611718      8.108718     20.999695      6.414517     52.609027
#
#           STATION_6     STATION_7     STATION_8     STATION_9    STATION_10  \
# count  28481.000000  28481.000000  28481.000000  28481.000000  28481.000000
# mean      -0.104563     -1.306425      0.579137     -0.494502      0.425271
# std        0.518288      2.210467      2.728087      0.607453      2.044501
# min       -3.518718    -45.678429    -46.760383     -3.316298     -7.795198
# 25%       -0.455583     -2.359852     -0.824010     -0.846290     -1.100203
# 50%       -0.120919     -1.482784      0.455927     -0.452850      0.370170
# 75%        0.211711     -0.406622      1.802398     -0.054228      1.900483
# max        6.917807     29.187120     66.401992      3.504680     23.763734
#
#        ...    STATION_21    STATION_22    STATION_23    STATION_24  \
# count  ...  28481.000000  28481.000000  28481.000000  28481.000000
# mean   ...      1.164661      0.692386      1.431642     -1.168753
# std    ...      1.684368      0.594955      0.840303      1.980706
# min    ...    -14.383959    -18.359777     -3.605645     -9.706114
# 25%    ...      0.357461      0.531007      0.932726     -2.478610
# 50%    ...      1.290120      0.683986      1.434358     -1.147799
# 75%    ...      2.124500      0.844503      1.933759      0.135020
# max    ...     42.316499     18.303560     10.104239      6.517474
#
#          STATION_25    STATION_26    STATION_27    STATION_28    STATION_29  \
# count  28481.000000  28481.000000  28481.000000  28481.000000  28481.000000
# mean      -0.366982      2.221551      0.670688      0.293530     18.805597
# std        1.927449      2.245670      2.637149      1.225971     26.996847
# min      -15.735926    -39.731350    -43.198220    -25.952903     10.000000
# 25%       -1.351416      1.517745     -0.863844     -0.276105     10.549000
# 50%       -0.469975      2.116069      0.110172      0.249667     12.200000
# 75%        0.462626      2.762948      1.472703      0.847806     17.648000
# max       36.636038     69.897540     28.704501     31.482148   1975.653000
#
#          STATION_31
# count  28481.000000
# mean       3.966188
# std        2.596470
# min        0.000000
# 25%        2.000000
# 50%        4.000000
# 75%        6.000000
# max        8.000000
#
# [8 rows x 30 columns]
